# %%
#import libraries
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
import time

# %%
#scrap neighbourhood data from Wikipedia
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
data = requests.get(url)

# %%
#use beautifulsoup to pull table data and organize into dataframe
soup = BeautifulSoup(data.text, 'html.parser')
tableContent = soup.table.find_all('td')

#initiate main list and sub-list
x = []
y = []

#loop through entire list
for z in range(int(len(tableContent))):
    #append values into sub-list and remove line breaks
    y.append(tableContent[z].text.replace('\n',''))
    #for every third value, append sub-list to main list and reset sub-list
    if z % 3 == 2:
        x.append(y)
        y = []

#parse main list into a dataframe
df = pd.DataFrame(x)

#add column titles, delete borough column
df.columns = ['Postcode','Borough','Neighbourhood']

#check dataframe
print(df.shape)
df.head(10)
# Out:
# (289, 3)
#   Postcode           Borough     Neighbourhood
# 0      M1A      Not assigned      Not assigned
# 1      M2A      Not assigned      Not assigned
# 2      M3A        North York         Parkwoods
# 3      M4A        North York  Victoria Village
# 4      M5A  Downtown Toronto      Harbourfront
# 5      M5A  Downtown Toronto       Regent Park
# 6      M6A        North York  Lawrence Heights
# 7      M6A        North York    Lawrence Manor
# 8      M7A      Queen's Park      Not assigned
# 9      M8A      Not assigned      Not assigned

# %%
#remove rows where Neighbourhood = 'Not assigned'
df = df[df.Neighbourhood != 'Not assigned']

#sort values by postcode for easier observation
df = df.sort_values('Postcode')

#reset index
df.reset_index(inplace=True, drop=True)

print(df.shape)
df.head(10)
# Out:
# (211, 3)
#   Postcode      Borough   Neighbourhood
# 0      M1B  Scarborough           Rouge
# 1      M1B  Scarborough         Malvern
# 2      M1C  Scarborough  Highland Creek
# 3      M1C  Scarborough      Port Union
# 4      M1C  Scarborough      Rouge Hill
# 5      M1E  Scarborough       Guildwood
# 6      M1E  Scarborough     Morningside
# 7      M1E  Scarborough       West Hill
# 8      M1G  Scarborough          Woburn
# 9      M1H  Scarborough       Cedarbrae

# %%
#import libraries
import json # library to handle JSON files
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# import k-means from clustering stage
from sklearn.cluster import KMeans

# !pip install geopy
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values
# Out:
# Requirement already satisfied: geopy in c:\users\jerry\anaconda3\lib\site-packages (1.18.1)
# Requirement already satisfied: geographiclib<2,>=1.49 in c:\users\jerry\anaconda3\lib\site-packages (from geopy) (1.49)

# %%
def pullLatLong(address):
    geolocator = Nominatim(user_agent="foursquare_agent")
    location = geolocator.geocode(address)
    
    if location != None:
        latitude = location.latitude
        longitude = location.longitude
    else:
        latitude = 0
        longitude = 0
    
    print(address+': '+str(latitude)+', '+str(longitude))
    
    time.sleep(0.3)
    
    return {'lat':latitude, 'long':longitude}

# %%
df['Latitude'] = 0
df['Longitude'] = 0

for nbhd in df['Neighbourhood']:
    x = pullLatLong(nbhd+' , Toronto, Canada')
    df.loc[df['Neighbourhood'] == nbhd,'Latitude'] = x['lat']
    df.loc[df['Neighbourhood'] == nbhd,'Longitude'] = x['long']

print(df.shape)
df.head(10)
# Out:
# Rouge , Toronto, Canada: 43.8049304, -79.1658374
# Malvern , Toronto, Canada: 43.8091955, -79.2217008
# Highland Creek , Toronto, Canada: 43.7901172, -79.1733344
# Port Union , Toronto, Canada: 43.7755039, -79.1349765
# Rouge Hill , Toronto, Canada: 43.7802711, -79.1304992
# Guildwood , Toronto, Canada: 43.7548985, -79.1977755
# Morningside , Toronto, Canada: 43.7826012, -79.2049579
# West Hill , Toronto, Canada: 43.7689144, -79.1872905
# Woburn , Toronto, Canada: 43.7598243, -79.2252908
# Cedarbrae , Toronto, Canada: 43.75646655, -79.226692442588
# Scarborough Village , Toronto, Canada: 43.7437422, -79.2116324
# East Birchmount Park , Toronto, Canada: 43.7141672, -79.271109
# Ionview , Toronto, Canada: 43.7359904, -79.2765146
# Kennedy Park , Toronto, Canada: 43.724878, -79.2539688
# Clairlea , Toronto, Canada: 43.7088231, -79.2959856
# Golden Mile , Toronto, Canada: 43.7278414, -79.2876217
# 6      M1E  Scarborough     Morningside  43.782601 -79.204958
# 7      M1E  Scarborough       West Hill  43.768914 -79.187291
# 8      M1G  Scarborough          Woburn  43.759824 -79.225291
# 9      M1H  Scarborough       Cedarbrae  43.756467 -79.226692

# %%
# delete neighbourhoods that cannot be geocoded
df = df[df.Latitude !=0]

df.reset_index(inplace=True, drop=True)

print(df.shape)
df.head(10)
# Out:
# (198, 5)
#   Postcode      Borough   Neighbourhood   Latitude  Longitude
# 0      M1B  Scarborough           Rouge  43.804930 -79.165837
# 1      M1B  Scarborough         Malvern  43.809196 -79.221701
# 2      M1C  Scarborough  Highland Creek  43.790117 -79.173334
# 3      M1C  Scarborough      Port Union  43.775504 -79.134976
# 4      M1C  Scarborough      Rouge Hill  43.780271 -79.130499
# 5      M1E  Scarborough       Guildwood  43.754899 -79.197776
# 6      M1E  Scarborough     Morningside  43.782601 -79.204958
# 7      M1E  Scarborough       West Hill  43.768914 -79.187291
# 8      M1G  Scarborough          Woburn  43.759824 -79.225291
# 9      M1H  Scarborough       Cedarbrae  43.756467 -79.226692

# %%
#save foursquare credentials
CLIENT_ID = '3T1DC2OMPAW5IB2JWHWOTJXS4AHD11GWHAHLFO1K4CRUDLCH' # your Foursquare ID
CLIENT_SECRET = 'W54KY4ZVRZSHEGQEIPJTFZOI5QH3FHDKA5BDRRFWZQTJ4DJH' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentials:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentials:
# CLIENT_ID: 3T1DC2OMPAW5IB2JWHWOTJXS4AHD11GWHAHLFO1K4CRUDLCH
# CLIENT_SECRET:W54KY4ZVRZSHEGQEIPJTFZOI5QH3FHDKA5BDRRFWZQTJ4DJH

# %%
#define wanted columns
vencols = ['Neighbourhood','Latitude','Longitude','Venue_Name','Venue_Latitude',
               'Venue_Longitude','Venue_Category_1']

#define function to pull venues within the vicinity of each neighbourhood
def getNearbyVenues(nbhd, lat, lng):
    #initialize dataframe
    vendf = pd.DataFrame(columns=vencols)

    radius = 500
    LIMIT = 100
    url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
                CLIENT_ID, 
                CLIENT_SECRET, 
                VERSION, 
                lat, 
                lng, 
                radius, 
                LIMIT)
    results = requests.get(url).json()
    
    for item in results['response']['groups'][0]['items']:
        a = item['venue']['name']
        b = item['venue']['location']['lat']
        c = item['venue']['location']['lng']
        d = item['venue']['categories'][0]['name']
        rowdata = {'Neighbourhood':nbhd,'Latitude':lat,'Longitude':lng,
                   'Venue_Name': a,'Venue_Latitude': b,'Venue_Longitude': c,'Venue_Category_1': d}
        vendf = vendf.append(rowdata, ignore_index=True)

    return vendf

# %%
#initialize empty dataframe for venue data
df1 = pd.DataFrame(columns=vencols)

#pull venues around each neighbourhood
for nbhd in df['Neighbourhood']:
    print(nbhd)
    tempdf = getNearbyVenues(nbhd, df.loc[df['Neighbourhood'] == nbhd,'Latitude'].values[0],
                                df.loc[df['Neighbourhood'] == nbhd,'Longitude'].values[0])
    df1 = pd.concat([df1,tempdf])

df1.reset_index(inplace=True, drop=True)

df1
# Out:
# Rouge
# Malvern
# Highland Creek
# Port Union
# Rouge Hill
# Guildwood
# Morningside
# West Hill
# Woburn
# Cedarbrae
# Scarborough Village
# East Birchmount Park
# Ionview
# Kennedy Park
# Clairlea
# Golden Mile
# Oakridge
# Cliffcrest
# Cliffside
# Scarborough Village West
# Cliffside West
# Birch Cliff
# Dorset Park
# Scarborough Town Centre
# Wexford Heights
# 20         Guildwood  43.754899 -79.197776
# 21         Guildwood  43.754899 -79.197776
# 22         Guildwood  43.754899 -79.197776
# 23       Morningside  43.782601 -79.204958
# 24       Morningside  43.782601 -79.204958
# 25       Morningside  43.782601 -79.204958
# 26       Morningside  43.782601 -79.204958
# 27       Morningside  43.782601 -79.204958
# 28       Morningside  43.782601 -79.204958
# 29       Morningside  43.782601 -79.204958
# ...              ...        ...        ...
# 5701       Northwest  43.646547 -79.419526
# 5702       Northwest  43.646547 -79.419526
# 5703       Northwest  43.646547 -79.419526
# 5704       Northwest  43.646547 -79.419526
# 5705       Northwest  43.646547 -79.419526
# 5706       Northwest  43.646547 -79.419526
# 5707       Northwest  43.646547 -79.419526
# 5708       Northwest  43.646547 -79.419526
# 5709       Northwest  43.646547 -79.419526
# 5710       Northwest  43.646547 -79.419526
# 5711       Northwest  43.646547 -79.419526
# 5712       Northwest  43.646547 -79.419526
# 5713       Northwest  43.646547 -79.419526
# 5714       Northwest  43.646547 -79.419526
# 5715       Northwest  43.646547 -79.419526
# 5716       Northwest  43.646547 -79.419526
# 5717       Northwest  43.646547 -79.419526
# 5718       Northwest  43.646547 -79.419526
# 5719       Northwest  43.646547 -79.419526
# 5720       Northwest  43.646547 -79.419526
# 5721       Northwest  43.646547 -79.419526
# 5722       Northwest  43.646547 -79.419526
# 5723       Northwest  43.646547 -79.419526
# 5724       Northwest  43.646547 -79.419526
# 5725       Northwest  43.646547 -79.419526
# 5726       Northwest  43.646547 -79.419526
# 5727       Northwest  43.646547 -79.419526
# 5728       Northwest  43.646547 -79.419526
# 5729       Northwest  43.646547 -79.419526
# 5730       Northwest  43.646547 -79.419526
#
#                                   Venue_Name  Venue_Latitude  Venue_Longitude  \
# 0                                  Dean Park       43.804364       -79.169159
# 1                 Paul's Breakfast & Burgers       43.803835       -79.169825
# 2                         Shoppers Drug Mart       43.809202       -79.223320
# 3                                     Subway       43.806805       -79.222515
# 4                                  Pizza Hut       43.808326       -79.220616
# 5                                Pizza Pizza       43.806613       -79.221243
# 6                        Francois' No Frills       43.808518       -79.223399
# 7                         Shoppers Drug Mart       43.806489       -79.223024
# 8                                 McDonald's       43.806375       -79.221588
# 9                                   Circle K       43.808097       -79.220449
# 10                Real Fruit Bubble Tea 真果茶坊       43.806709       -79.222759
# 11                            Planet Fitness       43.806744       -79.219900
# 12                             Malvern Arena       43.808594       -79.216634
# 13                               Telfer park       43.807310       -79.226403
# 14                            Highland Creek       43.790281       -79.173703
# 15                              Canmore Park       43.792401       -79.178339
# 16                Port Union Waterfront Park       43.774967       -79.134393
# 17            Port Union Village Common Park       43.776261       -79.135047
# 18                     Rouge Hill GO Station       43.780229       -79.130855
# 19                      Guildwood GO Station       43.754977       -79.198372
# 20    U-Haul Moving & Storage at Kingston Rd       43.756207       -79.199094
# 21                        VIA Rail Guildwood       43.755070       -79.198014
# 22                                 Greenvale       43.756565       -79.199243
# 23                          Morningside Park       43.786546       -79.205322
# 24                               Tim Hortons       43.780719       -79.205147
# 25                            The Beer Store       43.783904       -79.204900
# 26                                    Subway       43.783552       -79.204596
# 27                               Tim Hortons       43.783251       -79.204401
# 28                        Shoppers Drug Mart       43.780768       -79.205160
# 29                               Food Basics       43.786554       -79.205343
# ...                                      ...             ...              ...
# 5701                        Otto's Bierhalle       43.643457       -79.422279
# 5702                                Get Well       43.649320       -79.421937
# 5703                                 Hanmoto       43.649505       -79.422768
# 5704                                   Fresh       43.645010       -79.415084
# 5705                      The County General       43.644755       -79.416257
# 5706                          SoSo Food Club       43.649375       -79.421602
# 5707                  Trinity Bellwoods Park       43.647072       -79.413756
# 5708                 The Lakeview Restaurant       43.649435       -79.420390
# 5709                              Oyster Boy       43.645124       -79.414259
# 5710                                  Carmen       43.644829       -79.415872
# 5711                                  Veghed       43.649224       -79.422326
# 5712                                 Le Swan       43.645102       -79.414830
# 5713                                 Ufficio       43.649439       -79.423014
# 5714              Poutini's House of Poutine       43.643355       -79.423108
# 5715                         Nova Era Bakery       43.649419       -79.422177
# 5716                            Lost & Found       43.649378       -79.424149
# 5717                            The Garrison       43.649227       -79.422333
# 5718                      The Theatre Centre       43.643241       -79.423264
# 5719                      The Tampered Press       43.650062       -79.417280
# 5720                Opera Bob's Public House       43.649565       -79.420054
# 5721                              Philistine       43.644802       -79.416030
# 5722   Trinity Bellwoods Dog Park - The Bowl       43.648625       -79.414443
# 5723                          The Great Hall       43.643406       -79.422156
# 5724                               Hello 123       43.643264       -79.423516
# 5725                            The Good Son       43.643449       -79.422678
# 5726                                   Aēsop       43.645074       -79.414492
# 5727                              69 Vintage       43.643441       -79.422927
# 5728                        The Dog and Bear       43.643447       -79.422772
# 5729                 Fat Bastard Burrito Co.       43.643286       -79.423243
# 5730                              Queen Star       43.643380       -79.423334
#
#                      Venue_Category_1
# 0                                Park
# 1                Fast Food Restaurant
# 2                            Pharmacy
# 3                      Sandwich Place
# 4                         Pizza Place
# 5                         Pizza Place
# 6                       Grocery Store
# 7                            Pharmacy
# 8                Fast Food Restaurant
# 9                   Convenience Store
# 10                    Bubble Tea Shop
# 11               Gym / Fitness Center
# 12                       Skating Rink
# 13                               Park
# 14                       Neighborhood
# 15                               Park
# 16                               Park
# 17                               Park
# 18                      Train Station
# 19                      Train Station
# 20                   Storage Facility
# 21                      Train Station
# 22                     Baseball Field
# 23                               Park
# 24                        Coffee Shop
# 25                         Beer Store
# 26                     Sandwich Place
# 27                        Coffee Shop
# 28                           Pharmacy
# 29                        Supermarket
# ...                               ...
# 5701                         Beer Bar
# 5702                              Bar
# 5703                 Asian Restaurant
# 5704                        Juice Bar
# 5705  Southern / Soul Food Restaurant
# 5706                 Asian Restaurant
# 5707                             Park
# 5708                            Diner
# 5709               Seafood Restaurant
# 5710                 Tapas Restaurant
# 5711    Vegetarian / Vegan Restaurant
# 5712              American Restaurant
# 5713               Italian Restaurant
# 5714                    Poutine Place
# 5715                           Bakery
# 5716                      Men's Store
# 5717                      Music Venue
# 5718                          Theater
# 5719                      Coffee Shop
# 5720                              Pub
# 5721                         Boutique
# 5722                          Dog Run
# 5723                      Event Space
# 5724    Vegetarian / Vegan Restaurant
# 5725                       Restaurant
# 5726                   Cosmetics Shop
# 5727                   Clothing Store
# 5728                        Gastropub
# 5729                    Burrito Place
# 5730                   Breakfast Spot
#
# [5731 rows x 7 columns]

# %%
#create dictionary including each unique venue category
venuecat2 = {el:'dummy' for el in df1['Venue_Category_1'].unique()}
print(venuecat2)
# Out:
# {'Park': 'dummy', 'Fast Food Restaurant': 'dummy', 'Pharmacy': 'dummy', 'Sandwich Place': 'dummy', 'Pizza Place': 'dummy', 'Grocery Store': 'dummy', 'Convenience Store': 'dummy', 'Bubble Tea Shop': 'dummy', 'Gym / Fitness Center': 'dummy', 'Skating Rink': 'dummy', 'Neighborhood': 'dummy', 'Train Station': 'dummy', 'Storage Facility': 'dummy', 'Baseball Field': 'dummy', 'Coffee Shop': 'dummy', 'Beer Store': 'dummy', 'Supermarket': 'dummy', 'Discount Store': 'dummy', 'Electronics Store': 'dummy', 'Fried Chicken Joint': 'dummy', 'Food & Drink Shop': 'dummy', 'Liquor Store': 'dummy', 'Smoothie Shop': 'dummy', 'Breakfast Spot': 'dummy', 'Sports Bar': 'dummy', 'Bank': 'dummy', 'Burger Joint': 'dummy', 'Greek Restaurant': 'dummy', 'Thrift / Vintage Store': 'dummy', 'Clothing Store': 'dummy', 'Video Game Store': 'dummy', 'Mexican Restaurant': 'dummy', 'Spa': 'dummy', 'Medical Center': 'dummy', 'Gym': 'dummy', 'Vietnamese Restaurant': 'dummy', 'Paper / Office Supplies Store': 'dummy', 'Toy / Game Store': 'dummy', 'Big Box Store': 'dummy', 'Furniture / Home Store': 'dummy', 'Luggage Store': 'dummy', 'Bus Station': 'dummy', 'Optical Shop': 'dummy', 'Shopping Mall': 'dummy', 'Pub': 'dummy', 'Chinese Restaurant': 'dummy', 'Gas Station': 'dummy', 'Deli / Bodega': 'dummy', 'Business Service': 'dummy', 'Metro Station': 'dummy', 'Asian Restaurant': 'dummy', 'Intersection': 'dummy', 'Burrito Place': 'dummy', 'Cosmetics Shop': 'dummy', 'Steakhouse': 'dummy', 'Warehouse Store': 'dummy', 'Japanese Restaurant': 'dummy', 'Health Food Store': 'dummy', 'Arts & Crafts Store': 'dummy', 'American Restaurant': 'dummy', 'Sporting Goods Shop': 'dummy', 'Laser Tag': 'dummy', 'Department Store': 'dummy', 'Shopping Plaza': 'dummy', 'Bridal Shop': 'dummy', 'Shoe Store': 'dummy', 'Frozen Yogurt Shop': 'dummy', 'IT Services': 'dummy', 'Pet Store': 'dummy', 'Leather Goods Store': 'dummy', 'Supplement Shop': 'dummy', 'Hardware Store': 'dummy', "Men's Store": 'dummy', "Women's Store": 'dummy', 'Accessories Store': 'dummy', 'Restaurant': 'dummy', 'Dessert Shop': 'dummy', 'Bus Stop': 'dummy', 'Gastropub': 'dummy', 'Gym Pool': 'dummy', 'Indian Restaurant': 'dummy', 'Latin American Restaurant': 'dummy', 'Wings Joint': 'dummy', 'Plaza': 'dummy', 'Bakery': 'dummy', 'Gaming Cafe': 'dummy', 'Tea Room': 'dummy', 'Movie Theater': 'dummy', 'Food Court': 'dummy', 'Italian Restaurant': 'dummy', 'Hobby Shop': 'dummy', 'Middle Eastern Restaurant': 'dummy', 'Mediterranean Restaurant': 'dummy', 'Bar': 'dummy', 'Korean Restaurant': 'dummy', 'Fish Market': 'dummy', 'Seafood Restaurant': 'dummy', 'Smoke Shop': 'dummy', 'Rental Car Location': 'dummy', 'Hakka Restaurant': 'dummy', 'Sushi Restaurant': 'dummy', 'Bowling Alley': 'dummy', 'Video Store': 'dummy', 'Bus Line': 'dummy', 'Hong Kong Restaurant': 'dummy', 'Cantonese Restaurant': 'dummy', 'Thai Restaurant': 'dummy', 'Market': 'dummy', 'Falafel Restaurant': 'dummy', 'Gift Shop': 'dummy', 'Caribbean Restaurant': 'dummy', 'Playground': 'dummy', 'Health & Beauty Service': 'dummy', 'Noodle House': 'dummy', 'Dumpling Restaurant': 'dummy', 'Snack Place': 'dummy', 'Miscellaneous Shop': 'dummy', 'Taiwanese Restaurant': 'dummy', 'Dongbei Restaurant': 'dummy', 'Athletics & Sports': 'dummy', 'Juice Bar': 'dummy', 'Ice Cream Shop': 'dummy', 'Taco Place': 'dummy', 'Diner': 'dummy', 'Recreation Center': 'dummy', 'Tennis Court': 'dummy', 'Art Museum': 'dummy', 'Ramen Restaurant': 'dummy', 'Café': 'dummy', 'Poke Place': 'dummy', 'Concert Hall': 'dummy', 'University': 'dummy', 'Art Gallery': 'dummy', 'Tapas Restaurant': 'dummy', 'Opera House': 'dummy', 'Jazz Club': 'dummy', 'Vegetarian / Vegan Restaurant': 'dummy', 'Salon / Barbershop': 'dummy', 'Monument / Landmark': 'dummy', 'Record Shop': 'dummy', 'Exhibit': 'dummy', 'Office': 'dummy', 'Hotel': 'dummy', 'Donut Shop': 'dummy', 'French Restaurant': 'dummy', 'Hot Dog Joint': 'dummy', 'Outdoor Supply Store': 'dummy', 'Wine Shop': 'dummy', 'Auto Dealership': 'dummy', 'Bookstore': 'dummy', 'Creperie': ' ...

# %%
#manually categorize unique venue categories into higher level (level 2) categories, convert into dataframe
venuecat22 = {'Park': 'Sports', 'Fast Food Restaurant': 'Dining', 'Chinese Restaurant': 'Dining', 'Pharmacy': 'Healthcare', 'Sandwich Place': 'Dining', 'Pizza Place': 'Dining', 'Grocery Store': 'Shopping', 'Convenience Store': 'Shopping', 'Bubble Tea Shop': 'Dining', 'Gym / Fitness Center': 'Sports', 'Skating Rink': 'Sports', 'Neighborhood': 'Entertainment', 'Train Station': 'Transport', 'Storage Facility': 'Business', 'Baseball Field': 'Sports', 'Coffee Shop': 'Dining', 'Beer Store': 'Nightlife', 'Supermarket': 'Shopping', 'Discount Store': 'Shopping', 'Electronics Store': 'Shopping', 'Fried Chicken Joint': 'Dining', 'Food & Drink Shop': 'Dining', 'Liquor Store': 'Nightlife', 'Smoothie Shop': 'Dining', 'Breakfast Spot': 'Dining', 'Sports Bar': 'Nightlife', 'Bank': 'Household', 'Greek Restaurant': 'Dining', 'Burger Joint': 'Dining', 'Salon / Barbershop': 'Household', 'Shopping Mall': 'Shopping', 'Video Game Store': 'Shopping', 'Mexican Restaurant': 'Dining', 'Spa': 'Entertainment', 'Medical Center': 'Healthcare', 'Gym': 'Sports', 'Vietnamese Restaurant': 'Dining', 'Paper / Office Supplies Store': 'Shopping', 'Toy / Game Store': 'Shopping', 'Big Box Store': 'Shopping', 'Furniture / Home Store': 'Shopping', 'Optical Shop': 'Shopping', 'Clothing Store': 'Shopping', 'Bar': 'Nightlife', 'Pub': 'Nightlife', 'Asian Restaurant': 'Dining', 'Deli / Bodega': 'Dining', 'Business Service': 'Business', 'Metro Station': 'Transport', 'Gas Station': 'Transport', 'Intersection': 'Transport', 'Diner': 'Dining', 'Burrito Place': 'Dining', 'Steakhouse': 'Dining', 'Cosmetics Shop': 'Shopping', 'Warehouse Store': 'Shopping', 'Health Food Store': 'Shopping', 'Japanese Restaurant': 'Dining', 'Arts & Crafts Store': 'Shopping', 'American Restaurant': 'Dining', 'Laser Tag': 'Entertainment', 'Sporting Goods Shop': 'Shopping', 'Department Store': 'Shopping', 'Shopping Plaza': 'Shopping', 'Bus Station': 'Transport', 'Bridal Shop': 'Shopping', 'Frozen Yogurt Shop': 'Dining', 'Automotive Shop': 'Shopping', 'Shoe Store': 'Shopping', 'IT Services': 'Business', 'Hardware Store': 'Shopping', 'Pet Store': 'Shopping', 'Leather Goods Store': 'Shopping', 'Supplement Shop': 'Healthcare', 'Kids Store': 'Shopping', "Men's Store": 'Shopping', 'Accessories Store': 'Shopping', 'Restaurant': 'Dining', 'Dessert Shop': 'Dining', 'Bus Stop': 'Transport', 'Wings Joint': 'Dining', 'Gym Pool': 'Sports', 'Indian Restaurant': 'Dining', 'Latin American Restaurant': 'Dining', 'Bakery': 'Dining', 'Gaming Cafe': 'Entertainment', 'Tea Room': 'Dining', 'Movie Theater': 'Entertainment', 'Italian Restaurant': 'Shopping', 'Food Court': 'Dining', 'Plaza': 'Shopping', "Women's Store": 'Shopping', 'Middle Eastern Restaurant': 'Dining', 'Mediterranean Restaurant': 'Dining', 'Hakka Restaurant': 'Dining', 'Sushi Restaurant': 'Dining', 'Video Store': 'Shopping', 'Bus Line': 'Transport', 'Korean Restaurant': 'Dining', 'Fish Market': 'Shopping', 'Seafood Restaurant': 'Dining', 'Smoke Shop': 'Shopping', 'Hong Kong Restaurant': 'Dining', 'Cantonese Restaurant': 'Dining', 'Thai Restaurant': 'Dining', 'Market': 'Shopping', 'Falafel Restaurant': 'Dining', 'Gift Shop': 'Shopping', 'Caribbean Restaurant': 'Dining', 'Playground': 'Entertainment', 'Health & Beauty Service': 'Shopping', 'Noodle House': 'Dining', 'Dumpling Restaurant': 'Dining', 'Snack Place': 'Dining', 'Miscellaneous Shop': 'Shopping', 'Taiwanese Restaurant': 'Dining', 'BBQ Joint': 'Dining', 'Dongbei Restaurant': 'Dining', 'Athletics & Sports': 'Shopping', 'Juice Bar': 'Dining', 'Ice Cream Shop': 'Dining', 'Taco Place': 'Dining', 'Recreation Center': 'Entertainment', 'Pool': 'Sports', 'Art Museum': 'Entertainment', 'Ramen Restaurant': 'Dining', 'Café': 'Dining', 'Concert Hall': 'Entertainment', 'University': 'Education', 'Poke Place': 'Dining', 'Art Gallery': 'Shopping', 'Tapas Restaurant': 'Dining', 'Opera House': 'Entertainment', 'Jazz Club': 'Entertainment', 'Gastropub': 'Nightlife', 'Vegetarian / Vegan Restaurant': 'Dining', 'Monument / Landmark': 'Entertainment', 'Record Shop': 'Shopping', 'Exhibit': 'Entertainment', 'Office': 'Business', 'Hotel': 'Entertainment', 'Donut Shop': 'Dining', 'French Restaurant': 'Dining', 'Hot Dog Joint': 'Dining', 'Tennis Court': 'Sports', 'Lawyer': 'Business', 'Outdoor Supply Store': 'Shopping', 'Wine Shop': 'Nightlife', 'Auto Dealership': 'Shopping', 'Bookstore': 'Shopping', 'Creperie': 'Dining', 'Udon Restaurant': 'Dining', 'Home Service': 'Entertainment', 'Karaoke Bar': 'Nightlife', 'Laundry Service': 'Household', 'Chocolate Shop': 'Shopping', 'Gourmet Shop': 'Shopping', 'Jewelry Store': 'Shopping', 'Hockey Arena': 'Sports', 'Pakistani Restaurant': 'Dining', 'Science Museum': 'Entertainment', 'Dance Studio': 'Sports', 'Nightclub': 'Nightlife', 'Bagel Shop': 'Dining', 'Construction & Landscaping': 'Business', 'Salad Place': 'Dining', 'Cafeteria': 'Dining', 'Beach': 'Sports', 'Nail Salon': 'Household', 'Tree': 'Entertainment', 'Martial Arts Dojo': 'Sports', 'Cheese Shop': 'Shopping', 'Afghan Restaurant': 'Dining', 'Turkish Restaurant': 'Dining', 'Yoga Studio': 'Sports', 'Music Venue': 'Entertainment', 'Sculpture Garden': 'Entertainment', 'Historic Site': 'Dining', 'Boat or Ferry': 'Transport', 'Fish & Chips Shop': 'Dining', 'Dim Sum Restaurant': 'Dining', 'Light Rail Station': 'Transport', 'Trail': 'Sports', 'Egyptian Restaurant': 'Dining', 'Brewery': 'Nightlife', 'Indian Chinese Restaurant': 'Dining', 'Indie Theater': 'Entertainment', 'Bistro': 'Dining', 'Scenic Lookout': 'Entertainment', 'Theater': 'Entertainment', 'Wine Bar': 'Nightlife', 'Aquarium': 'Entertainment', 'Baseball Stadium': 'Sports', 'Comedy Club': 'Entertainment', 'Brazilian Restaurant': 'Dining', 'Speakeasy': 'Nightlife', 'School': 'Education', 'Beer Bar': 'Nightlife', 'Soup Place': 'Dining', 'History Museum': 'Entertainment', 'Poutine Place': 'Dining', 'Cocktail Bar': 'Nightlife', 'Mobile Phone Shop': 'Shopping', 'Hobby Shop': 'Shopping', 'Lingerie Store': 'Shopping', 'Camera Store': 'Shopping', 'Massage Studio': 'Healthcare', 'Farmers Market': 'Shopping', 'Indoor Play Area': 'Entertainment', 'New American Restaurant': 'Dining', 'Cuban Restaurant': 'Dining', 'Boutique': 'Shopping', 'Mac & Cheese Joint': 'Dining', 'Southern / Soul Food Restaurant': 'Dining', 'Event Space': 'Entertainment', 'Dog Run': 'Entertainment', 'Butcher': 'Shopping', 'Mattress Store': 'Shopping', 'Castle': 'Entertainment', 'Museum': 'Entertainment', 'Jewish Restaurant': 'Dining', 'Chiropractor': 'Healthcare', 'Modern European Restaurant': 'Dining
venuecat22 = {'Venue_Category_1':list(venuecat22.keys()),'Venue_Category_2':list(venuecat22.values())}
venuecat22 = pd.DataFrame(venuecat22)

print(venuecat22['Venue_Category_2'].unique())
venuecat22.head(10)
# Out:
# ['Sports' 'Dining' 'Healthcare' 'Shopping' 'Entertainment' 'Transport'
#  'Business' 'Nightlife' 'Household' 'Education']
#        Venue_Category_1 Venue_Category_2
# 0                  Park           Sports
# 1  Fast Food Restaurant           Dining
# 2    Chinese Restaurant           Dining
# 3              Pharmacy       Healthcare
# 4        Sandwich Place           Dining
# 5           Pizza Place           Dining
# 6         Grocery Store         Shopping
# 7     Convenience Store         Shopping
# 8       Bubble Tea Shop           Dining
# 9  Gym / Fitness Center           Sports

# %%
#update original venues dataframe with level 2 categories
df2 = pd.merge(df1, venuecat22, on='Venue_Category_1')
df2 = df2.sort_values('Neighbourhood')
df2 = df2.reset_index(drop=True)

print(df2.shape)
df2.head(10)
# Out:
# (5714, 8)
#   Neighbourhood   Latitude  Longitude  \
# 0      Adelaide  43.650528 -79.379515
# 1      Adelaide  43.650528 -79.379515
# 2      Adelaide  43.650528 -79.379515
# 3      Adelaide  43.650528 -79.379515
# 4      Adelaide  43.650528 -79.379515
# 5      Adelaide  43.650528 -79.379515
# 6      Adelaide  43.650528 -79.379515
# 7      Adelaide  43.650528 -79.379515
# 8      Adelaide  43.650528 -79.379515
# 9      Adelaide  43.650528 -79.379515
#
#                                 Venue_Name  Venue_Latitude  Venue_Longitude  \
# 0                                     Leña       43.651751       -79.379021
# 1                         Cactus Club Cafe       43.649552       -79.381671
# 2                            The Gabardine       43.650988       -79.381225
# 3                     Assembly Chef's Hall       43.650579       -79.383412
# 4               The Omni King Edward Hotel       43.649191       -79.376006
# 5               The Adelaide Hotel Toronto       43.649831       -79.380164
# 6          One King West Hotel & Residence       43.648947       -79.377966
# 7  Cosmopolitan Toronto Centre Hotel & Spa       43.649064       -79.377598
# 8                 Cambridge Suites Toronto       43.651836       -79.378107
# 9                         Richmond Station       43.651569       -79.379266
#
#             Venue_Category_1 Venue_Category_2
# 0  Latin American Restaurant           Dining
# 1        American Restaurant           Dining
# 2        American Restaurant           Dining
# 3                 Food Court           Dining
# 4                      Hotel    Entertainment
# 5                      Hotel    Entertainment
# 6                      Hotel    Entertainment
# 7                      Hotel    Entertainment
# 8                      Hotel    Entertainment
# 9        American Restaurant           Dining

# %%
#summary of each venue category
df2.pivot_table(index=['Venue_Category_2'], aggfunc='size', fill_value=0)
# Out:
# Venue_Category_2
# Business           39
# Dining           3132
# Education          10
# Entertainment     432
# Healthcare         74
# Household          76
# Nightlife         466
# Shopping         1027
# Sports            355
# Transport         103
# dtype: int64

# %%
#count of venue categories by neighbourhood
df3 = df2.pivot_table(index=['Neighbourhood'], columns='Venue_Category_2', aggfunc='size', fill_value=0)

print(df3.shape)
df3.head(10)
# Out:
# (195, 10)
# Venue_Category_2  Business  Dining  Education  Entertainment  Healthcare  \
# Neighbourhood
# Adelaide                 1      54          0             11           0
# Agincourt                0       9          0              0           0
# Agincourt North          0      18          0              2           1
# Albion Gardens           0       1          0              3           0
# Alderwood                0       4          0              0           1
# Bathurst Manor           0       0          0              1           0
# Bathurst Quay            0      12          0              1           0
# Bayview Village          0       5          0              0           0
# Bedford Park             1       0          0              0           0
# Berczy Park              1      54          0             10           0
#
# Venue_Category_2  Household  Nightlife  Shopping  Sports  Transport
# Neighbourhood
# Adelaide                  1          8        20       4          1
# Agincourt                 0          0         1       0          2
# Agincourt North           1          2         7       0          0
# Albion Gardens            0          0         1       1          0
# Alderwood                 0          1         0       3          0
# Bathurst Manor            0          0         1       2          0
# Bathurst Quay             0          1         1       5          3
# Bayview Village           1          0         6       0          1
# Bedford Park              0          0         0       0          0
# Berczy Park               0         11        18       6          0

# %%
#create copy of df3, initiate df4 to rank top 10 locations for each category
df33 = df3
df4 = pd.DataFrame(columns=df33.columns)

for column in df33.columns:
    df33 = df33.sort_values(column, ascending=False)
    df4[column]=df33.index[0:10]

df4.index.rename('Rank',inplace=True)
df4.index += 1
df4
# Out:
# Venue_Category_2              Business                   Dining  \
# Rank
# 1                      Maple Leaf Park        Kensington Market
# 2                             Adelaide     First Canadian Place
# 3                 First Canadian Place                Chinatown
# 4                      Flemingdon Park          Design Exchange
# 5                          Golden Mile  Toronto Dominion Centre
# 6                          Grange Park           Commerce Court
# 7                            Guildwood               Willowdale
# 8                         Harbourfront         Willowdale South
# 9                    Harbourfront East          Willowdale West
# 10                   Harbourfront West                     King
#
# Venue_Category_2         Education            Entertainment        Healthcare  \
# Rank
# 1                        Jamestown                 CN Tower         Deer Park
# 2                 King and Spadina          Studio District       New Toronto
# 3                         Fairview         Princess Gardens           Malvern
# 4                      Mount Olive        Harbourfront West         Runnymede
# 5                 Princess Gardens        Harbourfront East     Lawrence Park
# 6                     Martin Grove             Harbourfront    St. James Town
# 7                         Richmond           Commerce Court  Parkdale Village
# 8                  Garden District                     King          Parkdale
# 9                      Grange Park                  Trinity          Maryvale
# 10                 Studio District  Toronto Dominion Centre         West Hill
#
# Venue_Category_2             Household                Nightlife  \
# Rank
# 1                     The Beaches West  Toronto Dominion Centre
# 2                          The Beaches                     King
# 3                            Parkwoods           Commerce Court
# 4                   The Junction North     First Canadian Place
# 5                            Runnymede          Little Portugal
# 6                        Lawrence Park          Design Exchange
# 7                       St. James Town     Church and Wellesley
# 8                   The Junction South       North Toronto West
# 9                 First Canadian Place                Northwest
# 10                        Martin Grove          Studio District
#
# Venue_Category_2                 Shopping             Sports  \
# Rank
# 1                        Lawrence Heights           CN Tower
# 2                               Yorkville  Harbourfront West
# 3                             Golden Mile       Harbourfront
# 4                         Garden District  Harbourfront East
# 5                                 Trinity   King and Spadina
# 6                             Grange Park           Richmond
# 7                 Scarborough Town Centre    Studio District
# 8                                Adelaide        The Beaches
# 9                           South Niagara   The Beaches West
# 10                               Richmond    Design Exchange
#
# Venue_Category_2          Transport
# Rank
# 1                         Runnymede
# 2                 The Danforth West
# 3                     Bathurst Quay
# 4                           Wexford
# 5                         Guildwood
# 6                         Riverdale
# 7                          Maryvale
# 8                          Parkdale
# 9                 Harbourfront West
# 10                 Thorncliffe Park

# %%
#cluster locations to compare similar clusters

#copy df, normalize data
df5 = df3
df5_norm = (df5 - df5.mean()) / (df5.max() - df5.min())

df5_norm.head(10)
# Out:
# Venue_Category_2  Business    Dining  Education  Entertainment  Healthcare  \
# Neighbourhood
# Adelaide               0.4  0.541978  -0.051282       0.366026   -0.189744
# Agincourt             -0.1 -0.100879  -0.051282      -0.092308   -0.189744
# Agincourt North       -0.1  0.027692  -0.051282      -0.008974    0.310256
# Albion Gardens        -0.1 -0.215165  -0.051282       0.032692   -0.189744
# Alderwood             -0.1 -0.172308  -0.051282      -0.092308    0.310256
# Bathurst Manor        -0.1 -0.229451  -0.051282      -0.050641   -0.189744
# Bathurst Quay         -0.1 -0.058022  -0.051282      -0.050641   -0.189744
# Bayview Village       -0.1 -0.158022  -0.051282      -0.092308   -0.189744
# Bedford Park           0.4 -0.229451  -0.051282      -0.092308   -0.189744
# Berczy Park            0.4  0.541978  -0.051282       0.324359   -0.189744
#
# Venue_Category_2  Household  Nightlife  Shopping    Sports  Transport  \
# Neighbourhood
# Adelaide           0.203419   0.400733  0.288889  0.217949   0.117949
# Agincourt         -0.129915  -0.170696 -0.083660 -0.182051   0.367949
# Agincourt North    0.203419  -0.027839  0.033987 -0.182051  -0.132051
# Albion Gardens    -0.129915  -0.170696 -0.083660 -0.082051  -0.132051
# Alderwood         -0.129915  -0.099267 -0.103268  0.117949  -0.132051
# Bathurst Manor    -0.129915  -0.170696 -0.083660  0.017949  -0.132051
# Bathurst Quay     -0.129915  -0.099267 -0.083660  0.317949   0.617949
# Bayview Village    0.203419  -0.170696  0.014379 -0.182051   0.117949
# Bedford Park      -0.129915  -0.170696 -0.103268 -0.182051  -0.132051
# Berczy Park       -0.129915   0.615018  0.249673  0.417949  -0.132051
#
# Venue_Category_2   Cluster
# Neighbourhood
# Adelaide         -0.373077
# Agincourt        -0.123077
# Agincourt North   0.376923
# Albion Gardens   -0.123077
# Alderwood        -0.123077
# Bathurst Manor   -0.123077
# Bathurst Quay     0.376923
# Bayview Village  -0.123077
# Bedford Park     -0.123077
# Berczy Park      -0.373077

# %%
# set number of clusters
kclusters = 5

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(df5_norm)

# append clustering data to dataframe
df5_clustered = df5
df5_clustered['Cluster'] = kmeans.labels_

print(df5_clustered.shape)
df5_clustered.head(10)
# Out:
# (195, 11)
# Venue_Category_2  Business  Dining  Education  Entertainment  Healthcare  \
# Neighbourhood
# Adelaide                 1      54          0             11           0
# Agincourt                0       9          0              0           0
# Agincourt North          0      18          0              2           1
# Albion Gardens           0       1          0              3           0
# Alderwood                0       4          0              0           1
# Bathurst Manor           0       0          0              1           0
# Bathurst Quay            0      12          0              1           0
# Bayview Village          0       5          0              0           0
# Bedford Park             1       0          0              0           0
# Berczy Park              1      54          0             10           0
#
# Venue_Category_2  Household  Nightlife  Shopping  Sports  Transport  Cluster
# Neighbourhood
# Adelaide                  1          8        20       4          1        3
# Agincourt                 0          0         1       0          2        1
# Agincourt North           1          2         7       0          0        2
# Albion Gardens            0          0         1       1          0        1
# Alderwood                 0          1         0       3          0        1
# Bathurst Manor            0          0         1       2          0        1
# Bathurst Quay             0          1         1       5          3        2
# Bayview Village           1          0         6       0          1        1
# Bedford Park              0          0         0       0          0        1
# Berczy Park               0         11        18       6          0        3

# %%
import matplotlib.cm as cm # Matplotlib and associated plotting modules
import matplotlib.colors as colors
import folium # map rendering library

# %%
#add lat long to clustered df
df6 = df[['Neighbourhood','Latitude','Longitude']]
df6.set_index('Neighbourhood', inplace=True)
df6 = pd.merge(df6, df5_clustered, on='Neighbourhood')

print(df6.shape)
df6.head(10)
# Out:
# (197, 13)
#                  Latitude  Longitude  Business  Dining  Education  \
# Neighbourhood
# Rouge           43.804930 -79.165837         0       1          0
# Malvern         43.809196 -79.221701         0       5          0
# Highland Creek  43.790117 -79.173334         0       0          0
# Port Union      43.775504 -79.134976         0       0          0
# Rouge Hill      43.780271 -79.130499         0       0          0
# Guildwood       43.754899 -79.197776         1       0          0
# Morningside     43.782601 -79.204958         0       5          0
# West Hill       43.768914 -79.187291         0      18          0
# Woburn          43.759824 -79.225291         0       8          0
# Cedarbrae       43.756467 -79.226692         0       6          0
#
#                 Entertainment  Healthcare  Household  Nightlife  Shopping  \
# Neighbourhood
# Rouge                       0           0          0          0         0
# Malvern                     0           2          0          0         2
# Highland Creek              1           0          0          0         0
# Port Union                  0           0          0          0         0
# Rouge Hill                  0           0          0          0         0
# Guildwood                   0           0          0          0         0
# Morningside                 0           1          0          1         4
# West Hill                   1           2          1          3         8
# Woburn                      0           1          1          1         6
# Cedarbrae                   0           0          0          2        12
#
#                 Sports  Transport  Cluster
# Neighbourhood
# Rouge                1          0        1
# Malvern              3          0        0
# Highland Creek       1          0        1
# Port Union           2          0        1
# Rouge Hill           0          1        1
# Guildwood            1          2        1
# Morningside          2          0        1
# West Hill            1          0        0
# Woburn               1          0        0
# Cedarbrae            2          1        1

# %%
# create map
torontoLatLong = pullLatLong('Toronto, Canada')
map_clusters = folium.Map(location=[torontoLatLong['lat'], torontoLatLong['long']], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(df6['Latitude'], df6['Longitude'], df6.index, df6['Cluster']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# Toronto, Canada: 43.653963, -79.387207
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df5_clustered.groupby('Cluster').mean()
# Out:
# Venue_Category_2  Business     Dining  Education  Entertainment  Healthcare  \
# Cluster
# 0                 0.038462  21.807692        0.0       0.769231    1.461538
# 1                 0.150000   2.560000        0.0       0.520000    0.120000
# 2                 0.136364  23.068182        0.0       1.931818    0.500000
# 3                 0.800000  56.066667        0.0      10.666667    0.066667
# 4                 0.500000  45.300000        1.0      11.500000    0.100000
#
# Venue_Category_2  Household  Nightlife   Shopping    Sports  Transport
# Cluster
# 0                  1.115385   1.730769   5.653846  2.038462   1.000000
# 1                  0.070000   0.310000   1.190000  1.170000   0.410000
# 2                  0.568182   3.545455   9.954545  1.409091   0.454545
# 3                  0.533333  11.000000  11.266667  5.533333   1.000000
# 4                  0.700000   6.900000  15.400000  4.000000   0.100000
